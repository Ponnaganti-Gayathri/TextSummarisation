# %% [markdown]
# <a href="https://colab.research.google.com/github/Ponnaganti-Gayathri/TextSummarisation/blob/main/text_summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sacremoses==0.0.53
# !pip install datasets
# !pip install transformers
# !pip install torch torchvision torchaudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=c238ca85dc72bded84a097be126dc20498b540037aee9fd5549fe6b01db20bf0
#   Stored in directory: /root/.cache/pip/wheels/11/75/c6/a82d827a00df823caf211262900d2c024f5b3a775b82b45230
# Successfully built sacremoses
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
from transformers import pipeline

# %%
#loading the dataset
xsum_dataset = load_dataset(
    "xsum",
    version="1.2.0",
    cache_dir='/Documents/Huggin_Face/data'
)  # Note: We specify cache_dir to use predownloaded data.
xsum_dataset
# The printed representation of this object shows the `num_rows`
# of each dataset split.
# Out:
# ...
# Generating test split:   0%|          | 0/11334 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-8-7cab012d88f7> in <cell line: 0>()
#       1 #loading the dataset
# ----> 2 xsum_dataset = load_dataset(
#       3     "xsum",
#       4     version="1.2.0",
#       5     # Remove cache_dir argument as loading from a local filesystem specified here is not supported
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2147         keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    2148     )
# ...

# %%
summarizer = pipeline(
    task="summarization",
    model="t5-small",
    min_length=20,
    max_length=40,
    truncation=True,
    model_kwargs={"cache_dir": '/Documents/Huggin_Face/'},
)  # Note: We specify cache_dir to use predownloaded models.
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cuda:0

# %% [markdown]
# 1. Mx len 512
# 2. if more than that use chunks(yet to update).

# %%
# Ask the user for input
input_text = input("Enter the text you want to summarize: ")

# Generate the summary
summary = summarizer(input_text, max_length=10000, min_length=30, do_sample=False)[0]['summary_text']

bullet_points = summary.split(". ")

for point in bullet_points:

    print(f"- {point}")

# Print the generated summary
print("Summary:", summary)
# Out:
# Enter the text you want to summarize: Lord Krishna is a major god in Hinduism, considered the eighth avatar of Vishnu and a central figure in the Mahabharata and Bhagavad Gita. He is revered as a warrior, hero, teacher, and philosopher, and is a beloved figure for many Hindus. His birth story, his childhood in Vrindavan, and his role in the battle of Kurukshetra are well-known.  Here's a more detailed look at some key aspects of Lord Krishna: 1. Birth and Childhood: Born in Mathura to Devaki and Vasudeva, he was imprisoned by his maternal uncle Kamsa. Kamsa feared a prophecy that Devaki's eighth child would kill him, so he imprisoned Devaki and Vasudeva. Vasudeva smuggled Krishna out of prison and raised him in Vrindavan with Nanda and Yasoda. His childhood was marked by playful mischief, herding cows, and playing his flute.  2. Key Roles and Teachings: Warrior and Charioteer: He played a crucial role in the Mahabharata, serving as Arjuna's charioteer and guiding him with wisdom duri
# ...
